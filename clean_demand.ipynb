# %% [markdown]
# # UIUC Grid Demand with Echo State Networks
#
# This notebook uses an Echo State Network(ESN) (from ``pyESN``) to predict
# the demand at the University of Illinois.
#
# The following items are included:
# 1. An initial demonstration of the ESN with a 72-hour prediction.
# 2. Grid optimization over spectral radius and noise
# 3. Grid optimization over reservoir size and sparsity
# 4. Demonstrate the effect of training length on accuracy.
# 5. A final demonstration of the ESN with optimized hyper-parameters.
#
# ### 1. Initial Demonstration

# %%
# import libraries
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# custom libraries
from tools import MSE, esn_prediction, param_string, optimal_values
from optimizers import grid_optimizer
from pyESN.pyESN import ESN

# %%
# import demand data
dataframe = pd.read_csv("data/uiuc_demand_data.csv", usecols=['time','kw'])
demand = np.array(dataframe.kw).astype('float64')

# normalize
norm = np.linalg.norm(demand)
demand_norm = demand/norm

# %%
params = {'n_reservoir':1000, 
          'sparsity':0.1, 
          'rand_seed':85, 
          'rho':1.5, 
          'noise':0.0001, 
          'future':72, 
          'window':None, 
          'trainlen':8000}

# %%
futureTotal = params['future']
time_range = np.array(dataframe.time)
hour_range = np.arange(0, len(time_range), 1)

# %%
tic = time.perf_counter()

init_pred = esn_prediction(demand_norm, params)

toc = time.perf_counter()
elapsed = toc - tic
print(f"This simulation took {elapsed:0.02f} seconds")
print(f"This simulation took {elapsed/60:0.02f} minutes")
# Out:
# This simulation took 3.33 seconds
# This simulation took 0.06 minutes

# %%
plt.figure(figsize=(16,9))
plt.suptitle("UIUC Demand Prediction with ESN", fontsize=21)
plt.title(param_string(params))
plt.ylabel("UIUC Demand [kW]", fontsize=16)
plt.xlabel(f"Hours since {time_range[0]}", fontsize=16)
# plot the truth
plt.plot(hour_range[-2*futureTotal:],norm*demand_norm[-2*futureTotal:],'b',label="True Demand", 
         alpha=0.7,
         color='tab:blue')
# # plot the prediction
plt.plot(hour_range[-futureTotal:], norm*init_pred,  alpha=0.8, 
         label='ESN Prediction',
         color='tab:red',
         linestyle='-')
plt.legend()

# %% [markdown]
# ### 2. Grid Optimization Over Spectral Radius and Noise

# %%
radius_set = [0.5, 0.7, 0.9,  1,  1.1,1.3,1.5]
noise_set = [ 0.0001, 0.0003,0.0007, 0.001, 0.003, 0.005, 0.007,0.01]

radiusxnoise_loss = grid_optimizer(demand_norm,
                      params,
                      args=['rho', 'noise'],
                      xset=radius_set,
                      yset=noise_set,
                      verbose=True,
                      visualize=True)
# Out:
# Optimizing over ['rho', 'noise']:
# rho = 0.5, noise = 0.0001, MSE=0.0005147263141197072
# rho = 0.5, noise = 0.0003, MSE=0.00048782443148997053
# rho = 0.5, noise = 0.0007, MSE=0.00043891658035080856
# rho = 0.5, noise = 0.001, MSE=0.00041239164021295835
# rho = 0.5, noise = 0.003, MSE=0.00039527190440892486
# rho = 0.5, noise = 0.005, MSE=0.0004923327765743809
# rho = 0.5, noise = 0.007, MSE=0.0006286663293363784
# rho = 0.5, noise = 0.01, MSE=0.0008147778812596353
# rho = 0.7, noise = 0.0001, MSE=0.000446306327416837
# rho = 0.7, noise = 0.0003, MSE=0.00047115279003267347
# rho = 0.7, noise = 0.0007, MSE=0.000448866618573525
# rho = 0.7, noise = 0.001, MSE=0.00042857295016230154
# rho = 0.7, noise = 0.003, MSE=0.0004122260217376514
# rho = 0.7, noise = 0.005, MSE=0.0005270171489407264
# rho = 0.7, noise = 0.007, MSE=0.0006793164545735355
# rho = 0.7, noise = 0.01, MSE=0.0008718309230689563
# rho = 0.9, noise = 0.0001, MSE=0.00032488548441375885
# rho = 0.9, noise = 0.0003, MSE=0.0003442968526216916
# rho = 0.9, noise = 0.0007, MSE=0.0003957088107301208
# rho = 0.9, noise = 0.001, MSE=0.0004014538319553029
# rho = 0.9, noise = 0.003, MSE=0.000425958697196203
# rho = 0.9, noise = 0.005, MSE=0.000570412034870166
# rho = 0.9, noise = 0.007, MSE=0.0007429485054024967
# rho = 0.9, noise = 0.01, MSE=0.0009421706161904368
# rho = 1, noise = 0.0001, MSE=0.0004297885839757307
# rho = 1, noise = 0.0003, MSE=0.0003186663201146509
# rho = 1, noise = 0.0007, MSE=0.00033938792713207415
# rho = 1, noise = 0.001, MSE=0.00036547764027982033
# rho = 1, noise = 0.003, MSE=0.0004449987281798251
# rho = 1, noise = 0.005, MSE=0.0006014832808503939
# rho = 1, noise = 0.007, MSE=0.000778092426926611
# rho = 1, noise = 0.01, MSE=0.0009763070492789615
# rho = 1.1, noise = 0.0001, MSE=0.0004435815938425271
# rho = 1.1, noise = 0.0003, MSE=0.000378406336981759
# rho = 1.1, noise = 0.0007, MSE=0.00031382556358338395
# rho = 1.1, noise = 0.001, MSE=0.0003366818378419014
# rho = 1.1, noise = 0.003, MSE=0.0004769964553301026
# rho = 1.1, noise = 0.005, MSE=0.0006334902585009192
# rho = 1.1, noise = 0.007, MSE=0.0007976515123189871
# rho = 1.1, noise = 0.01, MSE=0.000982365162824412
# rho = 1.3, noise = 0.0001, MSE=0.00034304059997409896
# rho = 1.3, noise = 0.0003, MSE=0.00037040487035925994
# rho = 1.3, noise = 0.0007, MSE=0.0003521458210689199
# rho = 1.3, noise = 0.001, MSE=0.00036243911468241796
# rho = 1.3, noise = 0.003, MSE=0.0005647618080920592
# rho = 1.3, noise = 0.005, MSE=0.0007100996728761919
# rho = 1.3, noise = 0.007, MSE=0.0008369858388184357
# rho = 1.3, noise = 0.01, MSE=0.0009730652124780488
# rho = 1.5, noise = 0.0001, MSE=0.00023523853822208683
# rho = 1.5, noise = 0.0003, MSE=0.00030487175964466696
# rho = 1.5, noise = 0.0007, MSE=0.000363793835847313
# rho = 1.5, noise = 0.001, MSE=0.00038916792785303604
# rho = 1.5, noise = 0.003, MSE=0.0005000235999460372
# rho = 1.5, noise = 0.005, MSE=0.0005965996059860365
# rho = 1.5, noise = 0.007, MSE=0.0006926906685291151
# rho = 1.5, noise = 0.01, MSE=0.0008076150957624544

# %%
opt_radius, opt_noise = optimal_values(radiusxnoise_loss, radius_set, noise_set)
params['rho'] = opt_radius
params['noise'] = opt_noise
print(f'The optimal set is:\nspectrum radius = {opt_radius} \nnoise = {opt_noise}')
# Out:
# The optimal set is:
# spectrum radius = 1.5
# noise = 0.0001

# %% [markdown]
# ### 3. Grid Optimization Over Reservoir Size and Sparsity
#
# The algorithm is unstable when ``n_reservoir == trainlen``.

# %%
reservoir_set = [600, 800, 1000, 1500, 2000, 3000, 4000]
sparsity_set = [0.005, 0.01, 0.03, 0.05, 0.1, 0.15, 0.2]

sizexsparsity_loss = grid_optimizer(demand_norm,
                      params,
                      args=['n_reservoir', 'sparsity'],
                      xset=reservoir_set,
                      yset=sparsity_set,
                      verbose=True,
                      visualize=True)
# Out:
# Optimizing over ['n_reservoir', 'sparsity']:
# n_reservoir = 600, sparsity = 0.005, MSE=0.00023224249593620008
# n_reservoir = 600, sparsity = 0.01, MSE=0.00029839790086802655
# n_reservoir = 600, sparsity = 0.03, MSE=0.00021692198582000697
# n_reservoir = 600, sparsity = 0.05, MSE=0.00022308582000295782
# n_reservoir = 600, sparsity = 0.1, MSE=0.00027976336031970076
# n_reservoir = 600, sparsity = 0.15, MSE=0.00034502567658919526
# n_reservoir = 600, sparsity = 0.2, MSE=0.00029453369071737276
# n_reservoir = 800, sparsity = 0.005, MSE=0.0002326698091204126
# n_reservoir = 800, sparsity = 0.01, MSE=0.00024151162856137585
# n_reservoir = 800, sparsity = 0.03, MSE=0.00020944053203176326
# n_reservoir = 800, sparsity = 0.05, MSE=0.0002091278225031486
# n_reservoir = 800, sparsity = 0.1, MSE=0.00022613150724242153
# n_reservoir = 800, sparsity = 0.15, MSE=0.0002629732062834135
# n_reservoir = 800, sparsity = 0.2, MSE=0.00023801926762029868
# n_reservoir = 1000, sparsity = 0.005, MSE=0.0003021912427719335
# n_reservoir = 1000, sparsity = 0.01, MSE=0.00024441264227097653
# n_reservoir = 1000, sparsity = 0.03, MSE=0.0002938021038556819
# n_reservoir = 1000, sparsity = 0.05, MSE=0.0003077945104141523
# n_reservoir = 1000, sparsity = 0.1, MSE=0.00023523853822208683
# n_reservoir = 1000, sparsity = 0.15, MSE=0.0002681050280470514
# n_reservoir = 1000, sparsity = 0.2, MSE=0.00023148813306490978
# n_reservoir = 1500, sparsity = 0.005, MSE=0.0003554536014723805
# n_reservoir = 1500, sparsity = 0.01, MSE=0.00028153388829773636
# n_reservoir = 1500, sparsity = 0.03, MSE=0.0002605399374386837
# n_reservoir = 1500, sparsity = 0.05, MSE=0.00027220688338090455
# n_reservoir = 1500, sparsity = 0.1, MSE=0.0003155709124376424
# n_reservoir = 1500, sparsity = 0.15, MSE=0.00023703454564711048
# n_reservoir = 1500, sparsity = 0.2, MSE=0.00028130778938205084
# n_reservoir = 2000, sparsity = 0.005, MSE=0.00026318780533539463
# n_reservoir = 2000, sparsity = 0.01, MSE=0.0002737697903177216
# n_reservoir = 2000, sparsity = 0.03, MSE=0.00019967344738370998
# n_reservoir = 2000, sparsity = 0.05, MSE=0.0002713767031759564
# n_reservoir = 2000, sparsity = 0.1, MSE=0.00027338499604109275
# n_reservoir = 2000, sparsity = 0.15, MSE=0.0002523385419229328
# n_reservoir = 2000, sparsity = 0.2, MSE=0.0003060622612106981
# n_reservoir = 3000, sparsity = 0.005, MSE=0.0002196730343491739
# n_reservoir = 3000, sparsity = 0.01, MSE=0.0004282159333426347
# n_reservoir = 3000, sparsity = 0.03, MSE=0.0006007451047682685
# n_reservoir = 3000, sparsity = 0.05, MSE=0.0008116874612537463
# n_reservoir = 3000, sparsity = 0.1, MSE=0.0003581764114447189
# n_reservoir = 3000, sparsity = 0.15, MSE=0.00025810603950239395
# n_reservoir = 3000, sparsity = 0.2, MSE=0.0003131358742409262
# n_reservoir = 4000, sparsity = 0.005, MSE=0.000523397044066324
# n_reservoir = 4000, sparsity = 0.01, MSE=0.00045336476030867197
# n_reservoir = 4000, sparsity = 0.03, MSE=0.0004339002410988812
# n_reservoir = 4000, sparsity = 0.05, MSE=0.00044124006686337494
# n_reservoir = 4000, sparsity = 0.1, MSE=0.00042321809741560835
# n_reservoir = 4000, sparsity = 0.15, MSE=0.0006355321249041565
# n_reservoir = 4000, sparsity = 0.2, MSE=0.0006893132403905638

# %%
opt_size, opt_sparsity = optimal_values(sizexsparsity_loss, reservoir_set, sparsity_set)
params['n_reservoir'] = opt_size
params['sparsity'] = opt_sparsity
print(f'The optimal set is:\nreservoir size = {opt_size} \nsparsity = {opt_sparsity}')
# Out:
# The optimal set is:
# reservoir size = 2000
# sparsity = 0.03

# %% [markdown]
# ### 4. Demonstrate the Effect of Training Length
#
# Once again, the algorithm is unstable when ``n_reservoir == trainlen``.
#
# We should expect that MSE will decrease as training length increases.

# %%
trainingLengths = np.arange(4000,25000,300)
trainlen_loss = grid_optimizer(demand_norm,
                      params,
                      args=['trainlen'],
                      xset=trainingLengths,
                      verbose=True,
                      visualize=True)
# Out:
# Optimizing over ['trainlen']:
# trainlen = 4000, MSE=0.0006787466893412016
# trainlen = 4300, MSE=0.0006198836280293635
# trainlen = 4600, MSE=0.0006670760339399106
# trainlen = 4900, MSE=0.0004800996664881757
# trainlen = 5200, MSE=0.00041564257429987055
# trainlen = 5500, MSE=0.0004117699925699248
# trainlen = 5800, MSE=0.00031976766707893966
# trainlen = 6100, MSE=0.0002921778126329372
# trainlen = 6400, MSE=0.0002656203281849534
# trainlen = 6700, MSE=0.0006068217849040268
# trainlen = 7000, MSE=0.0009745415450263664
# trainlen = 7300, MSE=0.0004898255884503885
# trainlen = 7600, MSE=0.0002775155956097815
# trainlen = 7900, MSE=0.0002834929786033538
# trainlen = 8200, MSE=0.0002717920645408323
# trainlen = 8500, MSE=0.0006612167933040435
# trainlen = 8800, MSE=0.00039001019421366803
# trainlen = 9100, MSE=0.0004585343379831804
# trainlen = 9400, MSE=0.00041389147850719795
# trainlen = 9700, MSE=0.00029687576134865756
# trainlen = 10000, MSE=0.0003984791326312985
# trainlen = 10300, MSE=0.0002937740126815854
# trainlen = 10600, MSE=0.00024165866368516963
# trainlen = 10900, MSE=0.0002552697761252625
# trainlen = 11200, MSE=0.00040483597420683937
# trainlen = 11500, MSE=0.00027532281428345825
# trainlen = 11800, MSE=0.00048198840080177456
# trainlen = 12100, MSE=0.0003539188149361221
# trainlen = 12400, MSE=0.000507634942619817
# trainlen = 12700, MSE=0.00048088566840798474
# trainlen = 13000, MSE=0.00043005302578948823
# trainlen = 13300, MSE=0.00024488630773301245
# trainlen = 13600, MSE=0.00024939186527196444
# trainlen = 13900, MSE=0.00023186470613469653
# trainlen = 14200, MSE=0.0002697290317641509
# trainlen = 14500, MSE=0.0002898005820743162
# trainlen = 14800, MSE=0.00035152504523519796
# trainlen = 15100, MSE=0.000303652289476913
# trainlen = 15400, MSE=0.00027036201608974874
# trainlen = 15700, MSE=0.0002225313414250171
# trainlen = 16000, MSE=0.0003660644057215929
# trainlen = 16300, MSE=0.0002948003710092943
# trainlen = 16600, MSE=0.00020351542911239517
# trainlen = 16900, MSE=0.0002505301513974889
# trainlen = 17200, MSE=0.00026923233749783366
# trainlen = 17500, MSE=0.00022161686637399956
# trainlen = 17800, MSE=0.00036040354870681677
# trainlen = 18100, MSE=0.00027736811694256745
# trainlen = 18400, MSE=0.0003001462910173665
# trainlen = 18700, MSE=0.00026960966100685215
# trainlen = 19000, MSE=0.0002296358021215738
# trainlen = 19300, MSE=0.00022498498807850236
# trainlen = 19600, MSE=0.0002610273113874605
# trainlen = 19900, MSE=0.00032865141830593276
# trainlen = 20200, MSE=0.00023379438872996156
# trainlen = 20500, MSE=0.00028944099933202774
# trainlen = 20800, MSE=0.0004775751065969988
# trainlen = 21100, MSE=0.00021067123514254186
# trainlen = 21400, MSE=0.000203227374717364
# trainlen = 21700, MSE=0.0002688771595939203
# trainlen = 22000, MSE=0.0003573655280988567
# trainlen = 22300, MSE=0.0002913962585762619
# trainlen = 22600, MSE=0.00043030992806875295
# trainlen = 22900, MSE=0.00040546937648761684
# trainlen = 23200, MSE=0.00039159908390277434
# trainlen = 23500, MSE=0.0003435617977490673
# trainlen = 23800, MSE=0.0004150830670588879
# trainlen = 24100, MSE=0.00022641921703155132
# trainlen = 24400, MSE=0.0003726274776790397
# trainlen = 24700, MSE=0.000276591720056209

# %%
minloss = np.min(trainlen_loss)
index_min = np.where(trainlen_loss == minloss)
l_opt = trainingLengths[index_min][0]
params['trainlen'] = l_opt

print(f"Training length with minimum error was: {l_opt}")
# Out:
# Training length with minimum error was: 21400

# %% [markdown]
# ### 5. Optimized Demand Prediction

# %%
tic = time.perf_counter()

opt_pred = esn_prediction(demand_norm, params)

toc = time.perf_counter()
elapsed = toc - tic
print(f"This simulation took {elapsed:0.02f} seconds")
print(f"This simulation took {elapsed/60:0.02f} minutes")
# Out:
# This simulation took 84.93 seconds
# This simulation took 1.42 minutes

# %%
plt.figure(figsize=(16,9))
plt.suptitle("UIUC Demand Prediction with ESN", fontsize=21)
plt.title(param_string(params))
plt.ylabel("UIUC Demand [kW]", fontsize=16)
plt.xlabel(f"Hours since {time_range[0]}", fontsize=16)
# plot the truth
plt.plot(hour_range[-2*futureTotal:],norm*demand_norm[-2*futureTotal:],'b',label="True Demand", 
         alpha=0.7,
         color='tab:blue')
# # plot the prediction
plt.plot(hour_range[-futureTotal:], norm*opt_pred,  alpha=0.8, 
         label='ESN Prediction',
         color='tab:red',
         linestyle='-')
plt.legend()
