# %% [markdown]
# # UIUC Grid Demand: Demand + Solar Elevation Angle
#
# This notebook uses an Echo State Network(ESN) (from pyESN) to predict the demand at the University of Illinois.
# Rather than one input, there are two inputs: Demand and Solar Elevation Angle.
# The following items are included:
#
# 1. An initial demonstration of the ESN with a 72-hour prediction.
# 2. Grid optimization over spectral radius and noise
# 3. Grid optimization over reservoir size and sparsity
# 4. Demonstrate the effect of training length on accuracy.
# 5. A final demonstration of the ESN with optimized hyper-parameters.

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import sys
sys.path.insert(0, "/home/dotson/research/cairo")


# custom libraries
from tools import MSE, esn_prediction, param_string, optimal_values
from optimizers import grid_optimizer
from sunrise import generate_elevation_series
from pyESN.pyESN import ESN

# %%
# import demand data
dataframe = pd.read_csv("../data/uiuc_demand_data.csv", usecols=['time','kw'])
demand = np.array(dataframe.kw).astype('float64')

# normalize
norm = np.linalg.norm(demand)
demand_norm = demand/norm

# %%
time_range = pd.date_range(start='1/1/2015', end='7/1/2019', freq='h')[:-2]
elevation = generate_elevation_series(time_range, timestamps=True)
norm_a = np.linalg.norm(elevation)
angles_norm = elevation/norm_a
print(f"Norm of elevation angles: {norm_a}")
print(f"Norm of demand: {norm}")
# Out:
# Norm of elevation angles: 7170.040655802196
# Norm of demand: 10142199.043147163

# %% [markdown]
# ## Format the Input Data

# %%
X_in = np.concatenate([[demand_norm, angles_norm]], axis=1)
    
print(f"Shape of X_in is {X_in.shape}")
# Out:
# Shape of X_in is (2, 39407)

# %%
params = {'n_reservoir':1000, 
          'sparsity':0.1, 
          'rand_seed':85, 
          'rho':1.5, 
          'noise':0.0001, 
          'future':72, 
          'window':None, 
          'trainlen':8000}

# %%
futureTotal = params['future']
time_range = np.array(dataframe.time)
hour_range = np.arange(0, len(time_range), 1)

# %% [markdown]
# ## 1. Initial Demonstration

# %%
tic = time.perf_counter()

init_pred = esn_prediction(X_in.T, params)

toc = time.perf_counter()
elapsed = toc - tic
print(f"This simulation took {elapsed:0.02f} seconds")
print(f"This simulation took {elapsed/60:0.02f} minutes")
# Out:
# This simulation took 3.93 seconds
# This simulation took 0.07 minutes

# %%
plt.figure(figsize=(16,9))
plt.suptitle("UIUC Demand Prediction with ESN", fontsize=21)
plt.title(param_string(params))
plt.ylabel("UIUC Demand [kW]", fontsize=16)
plt.xlabel(f"Hours since {time_range[0]}", fontsize=16)
# plot the truth
plt.plot(hour_range[-2*futureTotal:],norm*demand_norm[-2*futureTotal:],'b',label="True Demand", 
         alpha=0.7,
         color='tab:blue')
# # plot the prediction
plt.plot(hour_range[-futureTotal:], norm*init_pred.T[0],  alpha=0.8, 
         label='ESN Prediction',
         color='tab:red',
         linestyle='-')
plt.legend()

# %% [markdown]
# ### 2. Grid Optimization Over Spectral Radius and Noise

# %%
tic = time.perf_counter()
radius_set = [0.5, 0.7, 0.9,  1,  1.1,1.3,1.5]
noise_set = [ 0.0001, 0.0003,0.0007, 0.001, 0.003, 0.005, 0.007,0.01]

radiusxnoise_loss = grid_optimizer(X_in.T,
                      params,
                      args=['rho', 'noise'],
                      xset=radius_set,
                      yset=noise_set,
                      verbose=True,
                      visualize=True)

toc = time.perf_counter()
elapsed = toc - tic
print(f"This simulation took {elapsed:0.02f} seconds")
print(f"This simulation took {elapsed/60:0.02f} minutes")
# Out:
# Optimizing over ['rho', 'noise']:
# rho = 0.5, noise = 0.0001, MSE=0.0034487437633518724
# rho = 0.5, noise = 0.0003, MSE=0.0029526150672816707
# rho = 0.5, noise = 0.0007, MSE=0.0026162106472787114
# rho = 0.5, noise = 0.001, MSE=0.002597094120966852
# rho = 0.5, noise = 0.003, MSE=0.0036381714450004635
# rho = 0.5, noise = 0.005, MSE=0.004431182799967146
# rho = 0.5, noise = 0.007, MSE=0.004772506392427107
# rho = 0.5, noise = 0.01, MSE=0.004948661695762623
# rho = 0.7, noise = 0.0001, MSE=0.0030097035548376774
# rho = 0.7, noise = 0.0003, MSE=0.003158686337854811
# rho = 0.7, noise = 0.0007, MSE=0.0029828179434518423
# rho = 0.7, noise = 0.001, MSE=0.0029945459429102416
# rho = 0.7, noise = 0.003, MSE=0.003643496812290268
# rho = 0.7, noise = 0.005, MSE=0.004508339454971034
# rho = 0.7, noise = 0.007, MSE=0.005069299545503106
# rho = 0.7, noise = 0.01, MSE=0.005428732330543783
# rho = 0.9, noise = 0.0001, MSE=0.0011173365756313944
# rho = 0.9, noise = 0.0003, MSE=0.001756208888248099
# rho = 0.9, noise = 0.0007, MSE=0.0026056653482489376
# rho = 0.9, noise = 0.001, MSE=0.0029713873469633667
# rho = 0.9, noise = 0.003, MSE=0.003936339460120015
# rho = 0.9, noise = 0.005, MSE=0.004471922485509609
# rho = 0.9, noise = 0.007, MSE=0.004954007322416656
# rho = 0.9, noise = 0.01, MSE=0.005459131052246669
# rho = 1, noise = 0.0001, MSE=0.0006747653002195322
# rho = 1, noise = 0.0003, MSE=0.0009343086578244287
# rho = 1, noise = 0.0007, MSE=0.0018232080647619076
# rho = 1, noise = 0.001, MSE=0.002423746366610471
# rho = 1, noise = 0.003, MSE=0.003932634122275259
# rho = 1, noise = 0.005, MSE=0.004416144294877288
# rho = 1, noise = 0.007, MSE=0.004805862038034988
# rho = 1, noise = 0.01, MSE=0.00528718975105194
# rho = 1.1, noise = 0.0001, MSE=0.0004756571852356653
# rho = 1.1, noise = 0.0003, MSE=0.0006775598802387557
# rho = 1.1, noise = 0.0007, MSE=0.0011726658903455952
# rho = 1.1, noise = 0.001, MSE=0.0017217958528606238
# rho = 1.1, noise = 0.003, MSE=0.0036955186527891336
# rho = 1.1, noise = 0.005, MSE=0.004255176960519013
# rho = 1.1, noise = 0.007, MSE=0.004589131394645079
# rho = 1.1, noise = 0.01, MSE=0.005020469756782967
# rho = 1.3, noise = 0.0001, MSE=0.0002929986946159774
# rho = 1.3, noise = 0.0003, MSE=0.00037861741878480705
# rho = 1.3, noise = 0.0007, MSE=0.0006579103201654052
# rho = 1.3, noise = 0.001, MSE=0.0008806743465161805
# rho = 1.3, noise = 0.003, MSE=0.0025010529282646268
# rho = 1.3, noise = 0.005, MSE=0.003587775415861295
# rho = 1.3, noise = 0.007, MSE=0.004149381882360676
# rho = 1.3, noise = 0.01, MSE=0.004600446395406797
# rho = 1.5, noise = 0.0001, MSE=0.0002501310103330221
# rho = 1.5, noise = 0.0003, MSE=0.00036263214240596245
# rho = 1.5, noise = 0.0007, MSE=0.0005313830119445995
# rho = 1.5, noise = 0.001, MSE=0.0006853206309068351
# rho = 1.5, noise = 0.003, MSE=0.0016599821643672047
# rho = 1.5, noise = 0.005, MSE=0.002453129192504205
# rho = 1.5, noise = 0.007, MSE=0.003109965782458082
# rho = 1.5, noise = 0.01, MSE=0.0038700211120211133
# This simulation took 255.84 seconds
# This simulation took 4.26 minutes

# %%
opt_radius, opt_noise = optimal_values(radiusxnoise_loss, radius_set, noise_set)
params['rho'] = opt_radius
params['noise'] = opt_noise
print(f'The optimal set is:\nspectrum radius = {opt_radius} \nnoise = {opt_noise}')
# Out:
# The optimal set is:
# spectrum radius = 1.5
# noise = 0.0001

# %% [markdown]
# ### 3. Grid Optimization Over Reservoir Size and Sparsity
#
# The algorithm is unstable when ``n_reservoir == trainlen``.

# %%
tic = time.perf_counter()
reservoir_set = [600, 800, 1000, 1500, 2000, 3000, 4000]
sparsity_set = [0.005, 0.01, 0.03, 0.05, 0.1, 0.15, 0.2]

sizexsparsity_loss = grid_optimizer(X_in.T,
                      params,
                      args=['n_reservoir', 'sparsity'],
                      xset=reservoir_set,
                      yset=sparsity_set,
                      verbose=True,
                      visualize=True)

toc = time.perf_counter()
elapsed = toc - tic
print(f"This simulation took {elapsed:0.02f} seconds")
print(f"This simulation took {elapsed/60:0.02f} minutes")
# Out:
# Optimizing over ['n_reservoir', 'sparsity']:
# n_reservoir = 600, sparsity = 0.005, MSE=0.0008626821005922485
# n_reservoir = 600, sparsity = 0.01, MSE=0.0008057118421403085
# n_reservoir = 600, sparsity = 0.03, MSE=0.0005247107827552032
# n_reservoir = 600, sparsity = 0.05, MSE=0.00044042239465092977
# n_reservoir = 600, sparsity = 0.1, MSE=0.0003776976729049712
# n_reservoir = 600, sparsity = 0.15, MSE=0.000605234284173659
# n_reservoir = 600, sparsity = 0.2, MSE=0.0005432840240050036
# n_reservoir = 800, sparsity = 0.005, MSE=0.00026116749599061016
# n_reservoir = 800, sparsity = 0.01, MSE=0.00028938674051999156
# n_reservoir = 800, sparsity = 0.03, MSE=0.0002761223761725781
# n_reservoir = 800, sparsity = 0.05, MSE=0.0002522329954162862
# n_reservoir = 800, sparsity = 0.1, MSE=0.0003064815114351696
# n_reservoir = 800, sparsity = 0.15, MSE=0.0002512640935250802
# n_reservoir = 800, sparsity = 0.2, MSE=0.00037390121948919944
# n_reservoir = 1000, sparsity = 0.005, MSE=0.00025692472763465176
# n_reservoir = 1000, sparsity = 0.01, MSE=0.0002806816616506302
# n_reservoir = 1000, sparsity = 0.03, MSE=0.00023290586092817981
# n_reservoir = 1000, sparsity = 0.05, MSE=0.000234898882688156
# n_reservoir = 1000, sparsity = 0.1, MSE=0.0002501310103330221
# n_reservoir = 1000, sparsity = 0.15, MSE=0.00020148230743591405
# n_reservoir = 1000, sparsity = 0.2, MSE=0.0002284961932650508
# n_reservoir = 1500, sparsity = 0.005, MSE=0.0003358535869329841
# n_reservoir = 1500, sparsity = 0.01, MSE=0.00021709857633908262
# n_reservoir = 1500, sparsity = 0.03, MSE=0.0002937122101389548
# n_reservoir = 1500, sparsity = 0.05, MSE=0.0002305833141716612
# n_reservoir = 1500, sparsity = 0.1, MSE=0.00029192008564552787
# n_reservoir = 1500, sparsity = 0.15, MSE=0.0002769094085919106
# n_reservoir = 1500, sparsity = 0.2, MSE=0.0002890073117272228
# n_reservoir = 2000, sparsity = 0.005, MSE=0.0002085121511466427
# n_reservoir = 2000, sparsity = 0.01, MSE=0.0002277405730635531
# n_reservoir = 2000, sparsity = 0.03, MSE=0.00027193255262711617
# n_reservoir = 2000, sparsity = 0.05, MSE=0.00024153696904627932
# n_reservoir = 2000, sparsity = 0.1, MSE=0.00023953804356857732
# n_reservoir = 2000, sparsity = 0.15, MSE=0.00026544613481729586
# n_reservoir = 2000, sparsity = 0.2, MSE=0.00023113339382991135
# n_reservoir = 3000, sparsity = 0.005, MSE=0.00025919427143045084
# n_reservoir = 3000, sparsity = 0.01, MSE=0.00023977122612504727
# n_reservoir = 3000, sparsity = 0.03, MSE=0.00027319144291229223
# n_reservoir = 3000, sparsity = 0.05, MSE=0.0003298007895018184
# n_reservoir = 3000, sparsity = 0.1, MSE=0.00033807919210893886
# n_reservoir = 3000, sparsity = 0.15, MSE=0.0004389120582454895
# n_reservoir = 3000, sparsity = 0.2, MSE=0.00032073157173523526
# n_reservoir = 4000, sparsity = 0.005, MSE=0.00043953155743903146
# n_reservoir = 4000, sparsity = 0.01, MSE=0.00026196676549549266
# n_reservoir = 4000, sparsity = 0.03, MSE=0.0002578552406605322
# n_reservoir = 4000, sparsity = 0.05, MSE=0.00020930031140583893
# n_reservoir = 4000, sparsity = 0.1, MSE=0.00018084134776125585
# n_reservoir = 4000, sparsity = 0.15, MSE=0.00019426418093218483
# n_reservoir = 4000, sparsity = 0.2, MSE=0.00021577737437228147
# This simulation took 1456.79 seconds
# This simulation took 24.28 minutes

# %%
opt_size, opt_sparsity = optimal_values(sizexsparsity_loss, reservoir_set, sparsity_set)
params['n_reservoir'] = opt_size
params['sparsity'] = opt_sparsity
print(f'The optimal set is:\nreservoir size = {opt_size} \nsparsity = {opt_sparsity}')
# Out:
# The optimal set is:
# reservoir size = 4000
# sparsity = 0.1

# %% [markdown]
# ### 4. Demonstrate the Effect of Training Length
#
# Once again, the algorithm is unstable when ``n_reservoir == trainlen``.
#
# We should expect that MSE will decrease as training length increases.

# %%
tic = time.perf_counter()
trainingLengths = np.arange(5000,25000,300)
trainlen_loss = grid_optimizer(X_in.T,
                      params,
                      args=['trainlen'],
                      xset=trainingLengths,
                      verbose=True,
                      visualize=True)

toc = time.perf_counter()
elapsed = toc - tic
print(f"This simulation took {elapsed:0.02f} seconds") 
print(f"This simulation took {elapsed/60:0.02f} minutes")
# Out:
# Optimizing over ['trainlen']:
# trainlen = 4000, MSE=110.56888115571184
# trainlen = 4300, MSE=0.0007237056064092541
# trainlen = 4600, MSE=0.0006129678674515721
# trainlen = 4900, MSE=0.0008994235137818919
# trainlen = 5200, MSE=0.000649928389446966
# trainlen = 5500, MSE=0.0003573071272834016
# trainlen = 5800, MSE=0.0005195831647832526
# trainlen = 6100, MSE=0.0003439500942448804
# trainlen = 6400, MSE=0.0007355784352756918
# trainlen = 6700, MSE=0.00031515377901982964
# trainlen = 7000, MSE=0.0002455636499706545
# trainlen = 7300, MSE=0.00039835723330664875
# trainlen = 7600, MSE=0.00041811866831796427
# trainlen = 7900, MSE=0.000205926481513521
# trainlen = 8200, MSE=0.0002895228937229625
# trainlen = 8500, MSE=0.000629797004272232
# trainlen = 8800, MSE=0.0003399187011939283
# trainlen = 9100, MSE=0.0003113306830011804
# trainlen = 9400, MSE=0.000292233004138259
# trainlen = 9700, MSE=0.00039252382646260255
# trainlen = 10000, MSE=0.00031722011811070703
# trainlen = 10300, MSE=0.00029636703537346156
# trainlen = 10600, MSE=0.0002529733745453682
# trainlen = 10900, MSE=0.00026592532812113933
# trainlen = 11200, MSE=0.0002129732176122108
# trainlen = 11500, MSE=0.00025198107221080637
# trainlen = 11800, MSE=0.00021569668234705543
# trainlen = 12100, MSE=0.00023591925332312337
# trainlen = 12400, MSE=0.0003210391380482599
# trainlen = 12700, MSE=0.0002621795934264543
# trainlen = 13000, MSE=0.00024928895222052077
# trainlen = 13300, MSE=0.000270664702506951
# trainlen = 13600, MSE=0.0002938876751568051
# trainlen = 13900, MSE=0.00031107833966181203
# trainlen = 14200, MSE=0.00022381365968448974
# trainlen = 14500, MSE=0.0002182701504796101
# trainlen = 14800, MSE=0.00021860696521276596
# trainlen = 15100, MSE=0.0002405449510272708
# trainlen = 15400, MSE=0.00020331728550233147
# trainlen = 15700, MSE=0.00021557874644883294
# trainlen = 16000, MSE=0.00031133247168894424
# trainlen = 16300, MSE=0.000374407036787488
# trainlen = 16600, MSE=0.00024404102513703415
# trainlen = 16900, MSE=0.00018639576057228975
# trainlen = 17200, MSE=0.00019949852969823085
# trainlen = 17500, MSE=0.00026447393766286124
# trainlen = 17800, MSE=0.00042790052118540104
# trainlen = 18100, MSE=0.00023486215863816707
# trainlen = 18400, MSE=0.00023246418468805618
# trainlen = 18700, MSE=0.00022049160707096561
# trainlen = 19000, MSE=0.0003114081750653363
# trainlen = 19300, MSE=0.00018823027137972466
# trainlen = 19600, MSE=0.0001874040667897287
# trainlen = 19900, MSE=0.00020916371577307623
# trainlen = 20200, MSE=0.00021103341813556131
# trainlen = 20500, MSE=0.0002088624238996275
# trainlen = 20800, MSE=0.00025060132063209117
# trainlen = 21100, MSE=0.0002071762136586788
# trainlen = 21400, MSE=0.00020626068335461705
# trainlen = 21700, MSE=0.0001723710227926425
# trainlen = 22000, MSE=0.00018680854096653885
# trainlen = 22300, MSE=0.00020684550835832168
# trainlen = 22600, MSE=0.00028222724589599104
# trainlen = 22900, MSE=0.00016719360347790423
# trainlen = 23200, MSE=0.0002070532909990568
# trainlen = 23500, MSE=0.000204147481469528
# trainlen = 23800, MSE=0.0001546184477394605
# trainlen = 24100, MSE=0.0002168483190145782
# trainlen = 24400, MSE=0.000344316971732279
# trainlen = 24700, MSE=0.00020544948051081762
# This simulation took 15100.66 seconds
# This simulation took 251.68 minutes

# %%
minloss = np.min(trainlen_loss)
index_min = np.where(trainlen_loss == minloss)
l_opt = trainingLengths[index_min][0]
params['trainlen'] = l_opt

print(f"Training length with minimum error was: {l_opt}")
# Out:
# Training length with minimum error was: 23800

# %% [markdown]
# ### 5. Optimized Demand Prediction

# %%
tic = time.perf_counter()

opt_pred = esn_prediction(X_in.T, params)

toc = time.perf_counter()
elapsed = toc - tic
print(f"This simulation took {elapsed:0.02f} seconds")
print(f"This simulation took {elapsed/60:0.02f} minutes")
# Out:
# This simulation took 209.97 seconds
# This simulation took 3.50 minutes

# %%
plt.figure(figsize=(16,9))
plt.suptitle("UIUC Demand Prediction with ESN", fontsize=21)
plt.title(param_string(params))
plt.ylabel("UIUC Demand [kW]", fontsize=16)
plt.xlabel(f"Hours since {time_range[0]}", fontsize=16)
# plot the truth
plt.plot(hour_range[-2*futureTotal:],norm*demand_norm[-2*futureTotal:],'b',label="True Demand", 
         alpha=0.7,
         color='tab:blue')
# # plot the prediction
plt.plot(hour_range[-futureTotal:], norm*opt_pred.T[0],  alpha=0.8, 
         label='ESN Prediction',
         color='tab:red',
         linestyle='-')
plt.legend()

# %% [markdown]
# ### Check a larger reservoir, for fun

# %%
nonopt_params = params
nonopt_params['n_reservoir'] = 8000

# %%
tic = time.perf_counter()

nonopt_pred = esn_prediction(X_in.T, nonopt_params)

toc = time.perf_counter()
elapsed = toc - tic
print(f"This simulation took {elapsed:0.02f} seconds")
print(f"This simulation took {elapsed/60:0.02f} minutes")
# Out:
# This simulation took 996.54 seconds
# This simulation took 16.61 minutes

# %%
plt.figure(figsize=(16,9))
plt.suptitle("UIUC Demand Prediction with ESN", fontsize=21)
plt.title(param_string(nonopt_params))
plt.ylabel("UIUC Demand [kW]", fontsize=16)
plt.xlabel(f"Hours since {time_range[0]}", fontsize=16)
# plot the truth
plt.plot(hour_range[-2*futureTotal:],norm*demand_norm[-2*futureTotal:],'b',label="True Demand", 
         alpha=0.7,
         color='tab:blue')
# # plot the prediction
plt.plot(hour_range[-futureTotal:], norm*nonopt_pred.T[0],  alpha=0.8, 
         label='ESN Prediction',
         color='tab:red',
         linestyle='-')
plt.legend()
